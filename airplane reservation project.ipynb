# %%
from tkinter import*
from tkinter import ttk
import datetime
import random
import time;
import tkinter.messagebox
import xlwt 
from xlwt import Workbook 
 

class Travel:
    
    def __init__(self, root):
        ############################
        self.root = root
        self.root.title("AirLine managment system")
        self.root.geometry("1518x680")
        self.root.resizable(0,0)
        self.root.configure(background='black')
        ##################################
        Dateoforder = StringVar()
        Dateoforder.set(time.strftime("%d/%m/%y"))
        Receipt_Ref = StringVar()
        P_2 = StringVar()
        P_3 = StringVar()
        P_4 = StringVar()
        ##########################
        var1 = IntVar()
        var2 = IntVar()
        var3 = IntVar()
        var4 = IntVar()
        var5 = IntVar()
        var6 = IntVar()
        var7 = IntVar()
        var8 = IntVar()
        var9 = IntVar()
        var10 = IntVar()
        var11 = StringVar()
        var12 = StringVar()        
        var13 = StringVar()
        var14 = StringVar()
        
        Firstname = StringVar()
        Surname = StringVar()
        Male = StringVar()
        Female = StringVar()
        Address = StringVar()
        PostCode = StringVar()
        Telephone = StringVar()
        Mobile = StringVar()
        Email = StringVar()
        
        Airportax = StringVar()
        Mile = StringVar()
        Travel_Ins = StringVar()
        Luggage = StringVar()
        
        Standard = StringVar()
        Economy = StringVar()
        FirstClass = StringVar()
        
        Airportax.set("0")
        Mile.set("0")
        Travel_Ins.set("0")
        Luggage.set("0")
        
        
        Standard.set("0")
        Economy.set("0")
        FirstClass.set("0")
        
       
        ######################################### Defined Function ############################################
        
        def Exit():
              Exit = tkinter.messagebox.askyesno("AirLine management system","confirm you want to exit")
              if Exit > 0:
                    root.destroy()
                    return
        
        def reset():
              
              Airportax.set("0")
              Mile.set("0")
              Travel_Ins.set("0")
              Luggage.set("0")
              
              Standard.set("0")
              Economy.set("0")
              FirstClass.set("0")
              
              Firstname.set("")
              Surname.set("")
              Address.set("")
              PostCode.set("")
              Telephone.set("")
              Mobile.set("")
              Email.set("")
              
              P_2.set("")
              P_3.set("")
              P_4.set("")
              self.check_Receipt_txt.delete("1.0", END)
              
              var1.set(0)
              var2.set(0)
              var3.set(0)
              var4.set(0)
              var5.set(0)
              var6.set(0)
              var7.set(0)
              var8.set(0)
              var9.set(0)
              var10.set(0)
              var11.set(0)
              var12.set(0)
              var13.set(0)
              
              
              self.check_Airportax_txt.configure(state=DISABLED)            
              self.check_Mile_txt.configure(state=DISABLED)
              self.check_Travel_Ins_txt.configure(state=DISABLED)
              self.check_Luggage_txt.configure(state=DISABLED)
        
              self.combo_To.current(0)
              self.combo_From.current(0)
              self.combo_Members.current(0)
              
        def Receipt():
              self.check_Receipt_txt.delete("1.0", END)
              x = random.randint(1123450, 11234560)
              rendomRef = str(x)
              Receipt_Ref.set(rendomRef)
              numbers = [45, 63, 223, 334]
              Sum = sum(numbers)
              self.check_Receipt_txt.insert(END, 'Receipt Ref:\t\t\t\t\t' + Receipt_Ref.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Date:\t\t\t\t\t' + Dateoforder.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Flight Travlling Details \n')
              self.check_Receipt_txt.insert(END, 'Name:\t\t\t\t\t' + Firstname.get()+" " + Surname.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Gender:\t\t\t\t\t'+ var14.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Address:\t\t\t\t\t' + Address.get() + "\n")
              self.check_Receipt_txt.insert(END, 'PostalCode:\t\t\t\t\t' + PostCode.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Telephone:\t\t\t\t\t' + Telephone.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Mobile:\t\t\t\t\t' + Mobile.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Email:\t\t\t\t\t'+ Email.get() + "\n")
              self.check_Receipt_txt.insert(END, 'From:\t\t\t\t\t'+ var11.get() + "\n")
              self.check_Receipt_txt.insert(END, 'To:\t\t\t\t\t'+ var12.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Total Passengers:\t\t\t\t\t'+ var13.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Second Passenger:\t\t\t\t\t' + P_2.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Third Passenger:\t\t\t\t\t' + P_3.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Fourth Passenger:\t\t\t\t\t' + P_4.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Airpor tax:\t\t\t\t\t'+ str(Airportax.get()) + "\n")
              self.check_Receipt_txt.insert(END, 'Air Mile:\t\t\t\t\t'+ str(Mile.get()) + "\n")
              self.check_Receipt_txt.insert(END, 'Travelling Insurance:\t\t\t\t\t'+ str(Travel_Ins.get()) + "\n")
              self.check_Receipt_txt.insert(END, 'Luggage:\t\t\t\t\t'+ str(Luggage.get()) + "\n")
              self.check_Receipt_txt.insert(END, 'Standard:\t\t\t\t\t'+ Standard.get() + "\n")
              self.check_Receipt_txt.insert(END, 'Economy:\t\t\t\t\t'+ Economy.get() + "\n")
              self.check_Receipt_txt.insert(END, 'FirstClass:\t\t\t\t\t'+ FirstClass.get() + "\n")
              print(var14.get())
              
        

              wb = Workbook() 
              sheet1 = wb.add_sheet('Sheet 1')
              sheet1.write(0, 0, 'Receipt Ref') 
              sheet1.write(1, 0, 'Date')  
              sheet1.write(2, 0, 'Name')
              sheet1.write(3, 0, 'Gender')
              sheet1.write(4, 0, 'Address')
              sheet1.write(5, 0, 'PostalCode')
              sheet1.write(6, 0, 'Telephone')
              sheet1.write(7, 0, 'Mobile')
              sheet1.write(8, 0, 'Email')
              sheet1.write(9, 0, 'From')
              sheet1.write(10, 0, 'To')
              sheet1.write(11, 0, 'Total Passengers')
              sheet1.write(12, 0, 'Second Passenger')
              sheet1.write(13, 0, 'Third Passenger')
              sheet1.write(14, 0, 'Fourth Passenger')
              sheet1.write(15, 0, 'Airport Tax')
              sheet1.write(16, 0, 'Air Mile')
              sheet1.write(17, 0, 'Travelling Insurance')
              sheet1.write(18, 0, 'Luggage')
              sheet1.write(19, 0, 'Standard')
              sheet1.write(20, 0, 'Economy')
              sheet1.write(21, 0, 'First Class')
              sheet1.write(0, 2, Receipt_Ref.get())
              sheet1.write(1, 2, Dateoforder.get())
              sheet1.write(2, 2, Firstname.get()+" " + Surname.get())
              sheet1.write(3, 2, var14.get())
              sheet1.write(4, 2, Address.get())
              sheet1.write(5, 2, PostCode.get())
              sheet1.write(6, 2, Telephone.get())
              sheet1.write(7, 2, Mobile.get())
              sheet1.write(8, 2, Email.get())
              sheet1.write(9, 2, var11.get())
              sheet1.write(10, 2, var12.get())
              sheet1.write(11, 2, var13.get())
              sheet1.write(12, 2, P_2.get())
              sheet1.write(13, 2, P_3.get())
              sheet1.write(14, 2, P_4.get())
              sheet1.write(15, 2, str(Airportax.get()))
              sheet1.write(16, 2, str(Mile.get()))
              sheet1.write(17, 2, str(Travel_Ins.get()))
              sheet1.write(18, 2, str(Luggage.get()))
              sheet1.write(19, 2, Standard.get())
              sheet1.write(20, 2, Economy.get())
              sheet1.write(21, 2, FirstClass.get())
              wb.save('Airline Receipt.xls')   

        def Airpor_tax():
              global paid1
              if (var1.get()==1):
                    self.check_Airportax_txt.configure(state = NORMAL)
                    Item1=float(45)
                    
                    Airportax.set("$" + str(Item1))
                    paid1 = Airportax.get()
                    Airportax.set("$" + str(Item1))
              elif var1.get()==0:
                    self.check_Airportax_txt.configure(state=DISABLED)
                    Airportax.set("0")
                    
              
        def Miles():
              global Item2
              if (var2.get()==1):
                    self.check_Mile_txt.configure(state = NORMAL)
                    Item2=(223)
                    
                    Mile.set("$" + str(Item2))
              elif var2.get()==0:
                    self.check_Mile_txt.configure(state=DISABLED)
                    Mile.set("0")      
              
        def Travelling_isu():
              global Item3
              if (var3.get()==1):
                    self.check_Travel_Ins_txt.configure(state = NORMAL)
                    Item3=float(63)
                    
                    Travel_Ins.set("$" + str(Item3))
              elif var3.get()==0:
                    self.check_Travel_Ins_txt.configure(state=DISABLED)
                    Travel_Ins.set("0")    
                      
        def Lug():
              
              global Item4
              if (var4.get()==1):
                    self.check_Luggage_txt.configure(state = NORMAL)
                    Item4=float(334)
                    Luggage.set("$" + str(Item4))
              elif var4.get()==0:
                    self.check_Luggage_txt.configure(state=DISABLED)
                    Travel_Ins.set("0")      
             
        def Standard_fees():
            global Item5
            if (var5.get()==1):
                  self.check_Standard_txt.configure(state = NORMAL)
                  Item5=float(274.9)
                  Standard.set("$" + str(Item5))
            elif var5.get()==0:
                  self.check_Standard_txt.configure(state=DISABLED)
                  Standard.set("0")
                      
        def Economy_fees():
            global Item6
            if (var7.get()==1):
                  self.check_Economy_txt.configure(state = NORMAL)
                  Item6=float(334.59)
                  Economy.set("$" + str(Item6))
            elif var7.get()==0:
                  self.check_Economy_txt.configure(state=DISABLED)
                  Economy.set("0")      
              
        def f_class():
            global Item7
            if (var9.get()==1):  
                  self.check_FirstClass_txt.configure(state=NORMAL)
                  Item7=float(547.6)
                  FirstClass.set("$" + str(Item7))
            elif (var9.get()==0):
                  self.check_FirstClass_txt.configure(state=DISABLED)
                  FirstClass.set("0")
              
        ######################################## Main Frame ####################################################
        MainFrame = Frame(self.root)
        MainFrame.grid()
        Tops = Frame(MainFrame, bd=20, width=1350, relief=RIDGE)
        Tops.pack(side=TOP)
        
        self.L0_titile =Label(Tops, text="AirLine Management Systems", font = ('arial', 70, 'bold'))
        self.L0_titile.grid()
        ##################################FRAMES#################################################################
        CustomerFrame = Frame(MainFrame, width=1350, height= 500, bd=20, pady=5, relief=RIDGE)
        CustomerFrame.pack(side=BOTTOM)
        
        CusDetailFrame = Frame(CustomerFrame, width=880, height= 400, bd=10,relief=RIDGE)
        CusDetailFrame.pack(side=LEFT)
        
        CustomerName = LabelFrame(CusDetailFrame, width=150, height= 250,text= "Customer Detail"
                                  ,font = ('arial', 12, 'bold'), bd=10, relief=RIDGE)
        CustomerName.grid(row=0, column=0)
        
        TravelFrame = LabelFrame(CusDetailFrame, width=300, height= 250,text= "Travel Detail" 
                                 ,font = ('arial', 12, 'bold'), bd=10, relief=RIDGE)
        TravelFrame.grid(row=0, column=1)
        
        TicketFrame = LabelFrame(CusDetailFrame, width=300, height= 150, relief=FLAT)
        TicketFrame.grid(row=1, column=0)
        
        CostFrame = LabelFrame(CusDetailFrame, width=150, height= 150,  relief=FLAT)
        CostFrame.grid(row=1, column=1)
        #####################################ButtonFrame###################################################
        Receipt_ButtonFrame = Frame(CustomerFrame, width=450, height= 400, bd=10,relief=RIDGE)
        Receipt_ButtonFrame.pack(side=RIGHT)
        
        ReceiptFrame  = LabelFrame(Receipt_ButtonFrame, width=350, height= 300,text= "Receipt"
                                  ,font = ('arial', 12, 'bold'), relief=RIDGE)
        ReceiptFrame.grid(row=0, column=0)
        
        ButtonFrame  = LabelFrame(Receipt_ButtonFrame, width=350, height=100
                                  )
        ButtonFrame.grid(row=1, column=0)
        #####################################CustomerFrame-LABELS/ENTRIES###########################################################
        self.f_L1 =Label(CustomerName, text="Firstname", font = ('arial', 14, 'bold'), bd=7)
        self.f_L1.grid(row=0, column=0, sticky=W)
        
        self.f_E1_txt =Entry(CustomerName, textvariable=Firstname ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.f_E1_txt.grid(row=0, column=1)
        
        self.s_L2 =Label(CustomerName, text="Surname", font = ('arial', 14, 'bold'), bd=7)
        self.s_L2.grid(row=1, column=0, sticky=W)
        
        self.s_E2_txt =Entry(CustomerName, textvariable=Surname ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.s_E2_txt.grid(row=1, column=1)
        
        self.A_L3 =Label(CustomerName, text="Address", font = ('arial', 14, 'bold'), bd=7)
        self.A_L3.grid(row=3, column=0, sticky=W)
        
        self.A_E3_txt =Entry(CustomerName, textvariable=Address ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.A_E3_txt.grid(row=3, column=1)
        
        self.P_L4 =Label(CustomerName, text="PostCode", font = ('arial', 14, 'bold'), bd=7)
        self.P_L4.grid(row=4, column=0, sticky=W)
        
        self.P_E4_txt =Entry(CustomerName, textvariable=PostCode ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.P_E4_txt.grid(row=4, column=1)
        
        self.T_L5 =Label(CustomerName, text="TelephoneNo.", font = ('arial', 14, 'bold'), bd=7)
        self.T_L5.grid(row=5, column=0, sticky=W)
        
        self.T_E5_txt =Entry(CustomerName, textvariable=Telephone ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.T_E5_txt.grid(row=5, column=1)
        
        self.M_L6 =Label(CustomerName, text="MobileNo.", font = ('arial', 14, 'bold'), bd=7)
        self.M_L6.grid(row=6, column=0, sticky=W)
        
        self.M_E6_txt =Entry(CustomerName, textvariable=Mobile, font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.M_E6_txt.grid(row=6, column=1)
        
        self.E_L7 =Label(CustomerName, text="Email", font = ('arial', 14, 'bold'), bd=7)
        self.E_L7.grid(row=7, column=0, sticky=W)
        
        self.E_E7_txt =Entry(CustomerName, textvariable=Email ,font = ('arial', 14, 'bold'), bd=7,
                             insertwidth=2, justify=LEFT)
        self.E_E7_txt.grid(row=7, column=1)
        
        self.Gender_L1 =Label(CustomerName, text="Gender",  font = ('arial', 14, 'bold'), bd=7)
        self.Gender_L1.grid(row=2, column=0, sticky=W)
        self.combo_Gender=ttk.Combobox(CustomerName, textvariable=var14, state='readonly', font = ('arial', 20, 'bold'),
                                          width=14)
        self.combo_Gender['value']=('',
                                'Male',
                                'Female',
                                       )
        self.combo_Gender.current(0)
        self.combo_Gender.grid(row=2, column=1) 
        

      ######################################TRAVEL Combo box################################################################  
        self.From_L1 =Label(TravelFrame, text="From", font = ('arial', 14, 'bold'), bd=7)
        self.From_L1.grid(row=0, column=0, sticky=W)
        
        self.combo_From=ttk.Combobox(TravelFrame, textvariable=var11, state='readonly', font = ('arial', 20, 'bold'),
                                          width=14)
        self.combo_From['value']=('',
                                       'Karachi',
                                       'Lahore',
                                       'Islamabad',
                                       'Rawalpindi',
                                       'Quetta',
                                       'Peshawar',
                                       'kohat',
                                       'Multan',
                                       'Faislabad',
                                       'hyderabad')
        self.combo_From.current(0)
        self.combo_From.grid(row=0, column=1)
        
        self.To_L2 =Label(TravelFrame, text="To", font = ('arial', 14, 'bold'), bd=7)
        self.To_L2.grid(row=1, column=0, sticky=W)
        
        self.combo_To=ttk.Combobox(TravelFrame, textvariable=var12, state='readonly', font = ('arial', 20, 'bold'),
                                          width=14)
        self.combo_To['value']=('',
                                       'Canada',
                                       'Dubai',
                                       'China',
                                       'Turkey',
                                       'Kuwait',
                                       'Palestine',
                                       'Austrailia',
                                       'Iraq',
                                       'England',
                                       'Nepal')
        self.combo_To.current(0)
        self.combo_To.grid(row=1, column=1)
        
        self.Members_L1 =Label(TravelFrame, text="Passengers", font = ('arial', 14, 'bold'), bd=7)
        self.Members_L1.grid(row=2, column=0, sticky=W)
        
        self.combo_Members=ttk.Combobox(TravelFrame, textvariable=var13, state='readonly', font = ('arial', 20, 'bold'),
                                          width=14)
        self.combo_Members['value']=('',
                                       '1',
                                       '2',
                                       '3',
                                       '4')
        self.combo_Members.current(0)
        self.combo_Members.grid(row=2, column=1)
        
               
###################################### check box ################################################################  
        self.check_Airportax = Checkbutton(TravelFrame, text="AirPort Tax",  command = Airpor_tax, variable=var1, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Airportax.grid(row=4, column=0, sticky=W)
        
        self.check_Airportax_txt=Entry(TravelFrame,font = ('arial', 14, 'bold'), textvariable=Airportax, bd=7, insertwidth=2,
                                       state=DISABLED, justify=LEFT)
        self.check_Airportax_txt.grid(row=4, column =1)
        
        self.check_Mile = Checkbutton(TravelFrame, text="Air Mile", variable=var2,command=Miles, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Mile.grid(row=5, column=0, sticky=W)
        
        self.check_Mile_txt=Entry(TravelFrame,font = ('arial', 14, 'bold'), textvariable=Mile, bd=7, insertwidth=2,
                                       state=DISABLED, justify=LEFT)
        self.check_Mile_txt.grid(row=5, column =1)
        
        self.check_Travel_Ins = Checkbutton(TravelFrame, text="Travelling Insurance",command=Travelling_isu, variable=var3, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Travel_Ins.grid(row=6, column=0, sticky=W)
        
        self.check_Travel_Ins_txt=Entry(TravelFrame,font = ('arial', 14, 'bold'), textvariable=Travel_Ins, bd=7, insertwidth=2,
                                       state=DISABLED, justify=LEFT)
        self.check_Travel_Ins_txt.grid(row=6, column =1)
        
        self.check_Luggage = Checkbutton(TravelFrame, text="Luggage",command=Lug ,variable=var4, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Luggage.grid(row=7, column=0, sticky=W)
        
        self.check_Luggage_txt=Entry(TravelFrame,font = ('arial', 14, 'bold'), textvariable=Luggage, bd=7, insertwidth=2,
                                       state=DISABLED, justify=LEFT)
        self.check_Luggage_txt.grid(row=7, column =1)
######################################payment box################################################################        
        
        self.Pad_tax = Label(CostFrame, text="Second Pessenger\t\t",
                                           font = ('arial', 12, 'bold'), bd=7)
        self.Pad_tax.grid(row=0, column=2, sticky=W)
        
        self.check_Pad_tax_txt=Entry(CostFrame,font = ('arial', 14, 'bold'), textvariable=P_2, bd=7, width=26,
                                        justify=LEFT)
        self.check_Pad_tax_txt.grid(row=0, column =3)
        
        self.check_Sub_total = Label(CostFrame, text="Third Pessenger\t\t",
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Sub_total.grid(row=1, column=2, sticky=W)
        
        self.check_Sub_total_txt=Entry(CostFrame,font = ('arial', 14, 'bold'), textvariable=P_3, bd=7, width=26,
                                        justify=LEFT)
        self.check_Sub_total_txt.grid(row=1, column =3)
        
        self.check_Totalcost = Label(CostFrame, text="Fourth Pessenger\t\t", 
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Totalcost.grid(row=2, column=2, sticky=W)
        
        self.check_Totalcost_txt=Entry(CostFrame,font = ('arial', 14, 'bold'), textvariable=P_4, bd=7, width=26,
                                        justify=LEFT)
        self.check_Totalcost_txt.grid(row=2, column =3)
        
        
############################################# Economy ###################################################################       
        
        self.check_Standard = Checkbutton(TicketFrame, text="Standard",command=Standard_fees, variable=var5, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Standard.grid(row=0, column=0, sticky=W)
        
        self.check_Standard_txt=Entry(TicketFrame,font = ('arial', 14, 'bold'), textvariable=Standard, bd=7, width=6,
                                       state=DISABLED, justify=LEFT)
        self.check_Standard_txt.grid(row=0, column =1)
        
        self.check_Single = Checkbutton(TicketFrame, text="Single", variable=var6, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Single.grid(row=0, column=2, sticky=W)
        
        
        self.check_Economy = Checkbutton(TicketFrame, text="Economy",command=Economy_fees, variable=var7, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Economy.grid(row=1, column=0, sticky=W)
        
        self.check_Economy_txt=Entry(TicketFrame,font = ('arial', 14, 'bold'), textvariable=Economy, bd=7, width=6,
                                       state=DISABLED, justify=LEFT)
        self.check_Economy_txt.grid(row=1, column =1)
        
        self.check_Return = Checkbutton(TicketFrame, text="Return", variable=var8, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_Return.grid(row=1, column=2, sticky=W)
        
        self.check_FirstClass = Checkbutton(TicketFrame, text="First Class",command=f_class, variable=var9, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_FirstClass.grid(row=2, column=0, sticky=W)
        
        self.check_FirstClass_txt=Entry(TicketFrame,font = ('arial', 14, 'bold'), textvariable=FirstClass, bd=7, width=6,
                                       state=DISABLED, justify=LEFT)
        self.check_FirstClass_txt.grid(row=2, column =1)
        
        self.check_SpecialNeed = Checkbutton(TicketFrame, text="Special Need", variable=var10, onvalue=1, offvalue=0,
                                           font = ('arial', 12, 'bold'), bd=7)
        self.check_SpecialNeed.grid(row=2, column=2, sticky=W)
        
#############################################Receipt###################################################################        
        self.check_Receipt_txt=Text(ReceiptFrame, width=60, height=21,font = ('arial', 10, 'bold'))
        self.check_Receipt_txt.grid(row=0, column=0)
        
 #############################################Button###################################################################        
        self.btn_Receipt = Button(ButtonFrame, text='Receipt', command=Receipt, padx=18, bd=7, width=4, font = ('arial', 16, 'bold')).grid(row=0, column=1)
        self.btn_Reset = Button(ButtonFrame, text='Reset', command=reset, padx=18, bd=7, width=4, font = ('arial', 16, 'bold')).grid(row=0, column=2)
        self.btn_Exit = Button(ButtonFrame, text='Exit', command= Exit, padx=18, bd=7, width=4, font = ('arial', 16, 'bold')).grid(row=0, column=3)

        
    
if __name__ =='__main__':
    root = Tk()
    application = Travel(root)
    root.mainloop()
